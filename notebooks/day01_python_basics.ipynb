# %%
x = 10
print(x)
print (type(x))
print(id(x))
# Out:
# 10
# <class 'int'>
# 140735066457496

# %% [markdown]
# Dynamic typing

# %%
x =[1,2,3]
print(x)
print(type(x))
print(id(x))
# Out:
# [1, 2, 3]
# <class 'list'>
# 2999993617408

# %% [markdown]
# FUnction is object

# %%
def hello():
    print("Hello")
print(type(hello))
# Out:
# <class 'function'>

# %% [markdown]
# type(True)	<class 'bool'>	Boolean: Represents a logical value of either True or False.
# type("Hello")	<class 'str'>	String: Represents text (a sequence of characters).
# type(3.14)	<class 'float'>	Floating-point number: Represents numbers with decimal points.
# type([1,2])	<class 'list'>	List: An ordered, mutable (changeable) collection of items.
# type({"a":1})	<class 'dict'>	Dictionary: A collection of key-value pairs (like a real-world dictionary where "a" is the word and 1 is the definition).

# %%
x =5
print(type(x))
print(type(3.14))
print(type({"a":1}))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'dict'>

# %%
name = "roy"
print(id(name))
name = name + "!"
print(name)
print(id(name))
# Out:
# 2999993776000
# roy!
# 2999993774416

# %%
acc = 96.333
print(f"acc = {acc:.2f}")
# Out:
# acc = 96.33

# %%
sen = "Daffodil International"
print(sen[0:10])
print(sen[::-1])
print(sen[::2])
print(sen[-5::])
# Out:
# Daffodil I
# lanoitanretnI lidoffaD
# Dfoi nentoa
# ional

# %%
sen = "Daffodil International"

word = sen.split()
print(word)

word1 = " ".join(word)
print(word1)
# Out:
# ['Daffodil', 'International']
# Daffodil International

# %%
s = "   AI is amazing   "
w = s.strip()
w1 = s.split()
print(w1)

output = "\n".join(w1)
print(output)
# Out:
# ['AI', 'is', 'amazing']
# AI
# is
# amazing
